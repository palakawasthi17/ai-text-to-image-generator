# %%
print("Hello, Jupyter!")
# Out:
# Hello, Jupyter!

# %%
print("Hello, Jupyter!")
# Out:
# Hello, Jupyter!

# %%
# !pip install diffusers transformers torch accelerate safetensors

# %%
import torch
from diffusers import StableDiffusionPipeline
from PIL import Image
import matplotlib.pyplot as plt

# %%
# Use Hugging Face's Stable Diffusion
pipe = StableDiffusionPipeline.from_pretrained(
    "runwayml/stable-diffusion-v1-5",
    torch_dtype=torch.float32
)
pipe = pipe.to("cpu")  # use "cpu" if no GPU
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
import torch
from diffusers import StableDiffusionPipeline
from PIL import Image
import matplotlib.pyplot as plt

# Check if GPU is available
device = "cuda" if torch.cuda.is_available() else "cpu"
dtype = torch.float16 if device == "cuda" else torch.float32

# Load the pipeline
pipe = StableDiffusionPipeline.from_pretrained(
    "runwayml/stable-diffusion-v1-5",
    torch_dtype=dtype
)

# Move model to correct device
pipe = pipe.to(device)

# Prompt input
prompt = "a futuristic city at sunset with flying cars"
image = pipe(prompt).images[0]

# Display
plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
import torch
from diffusers import StableDiffusionPipeline
from PIL import Image
import matplotlib.pyplot as plt

# Check if GPU is available
device = "cuda" if torch.cuda.is_available() else "cpu"
dtype = torch.float16 if device == "cuda" else torch.float32

# Load the pipeline
pipe = StableDiffusionPipeline.from_pretrained(
    "runwayml/stable-diffusion-v1-5",
    torch_dtype=dtype
)

# Move model to correct device
pipe = pipe.to(device)

# Prompt input
prompt = "a futuristic city at sunset with flying cars"
image = pipe(prompt).images[0]

# Display
plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
prompt = "a cyberpunk cityscape at night"
image = pipe(prompt).images[0]

# Display
plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
prompt = "a couple at top of burj khalifa"
image = pipe(prompt, height=384, width=384).images[0]


# Display
plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
prompt = "cleanliness drive"
image = pipe(prompt).images[0]


# Display
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
prompt = "war at night"
image = pipe(prompt).images[0]

# Display
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
import torch
from diffusers import StableDiffusionPipeline
from PIL import Image
import matplotlib.pyplot as plt

# Check if GPU is available
device = "cuda" if torch.cuda.is_available() else "cpu"
dtype = torch.float16 if device == "cuda" else torch.float32

# Load the pipeline
pipe = StableDiffusionPipeline.from_pretrained(
    "runwayml/stable-diffusion-v1-5",
    torch_dtype=dtype
)

# Move model to correct device
pipe = pipe.to(device)

# Prompt input
prompt = "war with flying cars"
image = pipe(prompt).images[0]

# Display
plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
prompt = "a fantasy landscape with castles and flying dragons"
image = pipe(prompt).images[0]

# Show the image
plt.imshow(image)
plt.axis('off')
plt.show()

# Save it
image.save("output/fantasy_image.png")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 10
#       7 plt.show()
#       9 # Save it
# ---> 10 image.save("output/fantasy_image.png")
#
# File /opt/anaconda3/lib/python3.13/site-packages/PIL/Image.py:2591, in Image.save(self, fp, format, **params)
#    2589         fp = builtins.open(filename, "r+b")
#    2590     else:
# -> 2591         fp = builtins.open(filename, "w+b")
#    2592 else:
#    2593     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output/fantasy_image.png'

# %%
prompt = "fantasy landscape with a castle"
image = pipe(prompt).images[0]

# Show the image
plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
